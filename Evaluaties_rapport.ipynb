# %% [markdown]
# # Evaluaties 5WeWiIn dit formulier bekijken we de evaluaties of meningen van de leerlingen over dit project. Deze werden gegeven in het formulier https://docs.google.com/forms/d/e/1FAIpQLSc6cKRk8KpxvJTB6Ye3LfZ-7WzpuTGFQctkl9-XnK1eohK5XQ/viewform.De leerlingen vulden dit per 2 in, aangezien ze ook in duo's werkten.Een waarde van 1 betekent "helemaal eens", terwijl 5 betekent "helemaal oneens".

# %%
import pandasimport matplotlib.pylab as pltevalFile=pandas.read_csv("/home/sam/Documents/Lerarenopleiding/LIO/OOP/notebooks/Feedback project planeetbanen (Reacties) - Formulierreacties 1.csv")ax_x=0ax_y=0fig, ax=plt.subplots(4,2,sharey=True,figsize=(15,15))for key, rows in evalFile.iteritems():    if key=="Tijdstempel" or key=="Andere opmerkingen/suggesties?":        continue    ax[ax_x,ax_y].hist(evalFile[key]-0.5,bins=5,range=[0.5,5.5])    ax[ax_x,ax_y].set_ylabel("Aantal duo's")    ax[ax_x,ax_y].set_xlabel("Waarde")    ax[ax_x,ax_y].set_title(key)    if ax_y==0:        ax_y+=1    else:        ax_x+=1        ax_y=0fig.delaxes(ax[3,1])fig.tight_layout()

# %% [markdown]
# Verder was er ook een plaats voorzien waar ze andere opmeringen konden geven:

# %%
print(evalFile["Andere opmerkingen/suggesties?"])
# Out:
# 0                                                               superduper1                                                                      NaN2                                                                      NaN3                                                                zeer goed4    Interessant onderwerp, maar saai om naar te luisteren en in te voerenName: Andere opmerkingen/suggesties?
